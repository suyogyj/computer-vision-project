# %%
import matplotlib.pyplot as plt
import os

# %%
file = r"data\EuroSAT_RGB\AnnualCrop\AnnualCrop_2990.jpg"
img = plt.imread(file)
plt.imshow(img)

# %%
all_types = os.listdir(r"data\EuroSAT_RGB")
for i in all_types:
    print(i)
    print(len(os.listdir(r"data\EuroSAT_RGB\\" + i)))
    print("")
# Out:
# AnnualCrop
# 3000
#
# Forest
# 3000
#
# HerbaceousVegetation
# 3000
#
# Highway
# 2500
#
# Industrial
# 2500
#
# Pasture
# 2000
#
# PermanentCrop
# 2500
#
# Residential
# 3000
#
# River
# 2500
#
# SeaLake
# 3000
